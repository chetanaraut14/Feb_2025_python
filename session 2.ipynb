# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\cheta\\Documents\\NareshIT\\python session'

# %%
getcwd === (get current working directory)
# Out:
# 1

# %%
# checkpoint-1:
# empty square bracket before the code cell
# indicates we did nor run the cell
# checkpoint-2:
# if we see a * mark inside square bracket
# do not run the next code cell
# start mark indicates kernel is busy
# the same we can observe the top left corner black dot

# %%
number =100

# %%
number
# Out:
# 100

# %%
number2=200

# %%
number2
# Out:
# 200

# %%
name="chetana"

# %%
name
# Out:
# 'chetana'

# %%
name = "chetna"

# %%
name
# Out:
# 'chetna'

# %% [markdown]
# hello today im learning python
#
# square bracket is there :yes
#
# code mode is there : yes
#
# if these two are there which indicates this current cell used for to write code only
#
# if you write english i will throw error
#
# go to top code mode after a drop down symbol is there
#
# click on that
#
# we can see markdown option
#
# select it then we can not see square bracket

# %% [markdown]
# # python

# %%
#python 
- shift+ enter
- esc+m will change code mode to markdown mode
- esc+y will change markdown to code mode
# Out:
#   Cell In[31], line 3
#     - esc+m will change code mode to markdown mode
#             ^
# SyntaxError: invalid syntax

# %%
#python

# %%
- hi chetana 
-

# %% [markdown]
# - Hi chetana
# - how are you
# - how do you do

# %% [markdown]
# # python
# ## python
# ### python

# %% [markdown]
# ** now i will show how to upload image **
#
# - but this will works for only some people
#
# - dont worry

# %% [markdown]
# <img src="https://i0.wp.com/junilearning.com/wp-content/uploads/2020/06/python-programming-language.webp?fit=800%2C800&amp;ssl=1" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 800px; height: 315px; margin: 0px; width: 315px;" alt="What is Python Coding? | Juni Learning" jsname="kn3ccd" aria-hidden="false">

# %% [markdown]
# CTRL + A
# CTRL + C
# CTRL + V
# ESC +M
# SHIFT + ENTER

# %% [markdown]
# <img src="https://blog.pwskills.com/wp-content/uploads/2024/03/10-Basic-Code-For-Python.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1280px; height: 219px; margin: 0.5px 0px; width: 351px;" alt="10 Basic Code For Python With Solution" jsname="kn3ccd" aria-hidden="false">mv
