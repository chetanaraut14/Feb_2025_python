# %% [markdown]
# # variables

# %% [markdown]
# - Variables are used to store the data
#
# - The data can be change
#
# - This variables can be use to manipulate python code

# %%
number = 100
# 100 is stored in a variable called as number
number
# Out:
# 100

# %%
NUMBER = 200
NUMBER
# Out:
# 200

# %%
NUMber = 300
NUMber
# Out:
# 300

# %%
number , NUMBER , NUMber
# Out:
# (100, 200, 300)

# %%
number123=400
number123
# Out:
# 400

# %%
# type first two letter enter tab
number
number123
# Out:
# 400

# %% [markdown]
# ** Note** :
#
# - Variables  generally in black color
#
# - Green color should not be a variables
#
# - number as suffix can work
#
# - number as prefix fail

# %%
number$=600
number$
# Out:
#   Cell In[28], line 1
#     number$=600
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Speacial characters are not allowed

# %%
number one=200
number one
# Out:
#   Cell In[1], line 1
#     number one=200
#            ^
# SyntaxError: invalid syntax

# %%
number_one=300
number_one
# Out:
# 300

# %% [markdown]
# - underscore can use as variable

# %%
number=100 ======= w
NUMBER=200 ======= w
NUMber=300 ======= w
number123=400 ======= w
123number=500 ======= f
number%=600 ======= f
number one=700 ======= f
number one=800 ======= w
_=900 ======= w
# Out:
#   Cell In[37], line 5
#     123number=500
#       ^
# SyntaxError: invalid decimal literal

# %%
if= 1000
# Out:
#   Cell In[39], line 1
#     if= 1000
#       ^
# SyntaxError: invalid syntax

# %%
for
while
True
False
# Out:
#   Cell In[41], line 1
#     for
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# - keywords can not use as Variables

# %%
6
